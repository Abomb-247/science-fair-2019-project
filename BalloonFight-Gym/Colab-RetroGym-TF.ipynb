# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %%
# !pip install gym-retro
# Out:
# ...
#      |████████████████████████████████| 162.0MB 94kB/s
# ...

# %%
# !python -m retro.import /gdrive/My\ Drive/science\ fair\ project/2019/ROMS/
# Out:
# Importing 2 potential games...
# Importing BalloonFight-Nes
# Imported 1 games

# %%
import retro
from stable_baselines.common.policies import MlpPolicy, MlpLstmPolicy, MlpLnLstmPolicy, CnnLnLstmPolicy, CnnPolicy, CnnLstmPolicy
from stable_baselines.common.vec_env import SubprocVecEnv, DummyVecEnv
from stable_baselines import PPO2, A2C
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
#env = DummyVecEnv([lambda: retro.make('BalloonFight-Nes', record='/gdrive/My Drive/science fair project/2019/BalloonFightRecord/')])
env = DummyVecEnv([lambda: retro.make('BalloonFight-Nes')])

# %%
modelname = 'balloonfightppo'
model = PPO2(CnnPolicy,env,n_steps=2048, verbose=1)
#model = PPO2.load("/gdrive/My Drive/science fair project/2019/BalloonFightRecord/" + modelname+".pkl")
for saveloop in range(100):
  print("saveloop = "+str(saveloop))
  for learnloop in range(15):
    print("learnloop = "+str(learnloop))
    model.learn(total_timesteps=10000)
  print("saving "+str(modelname))
  model.save("/gdrive/My Drive/science fair project/2019/BalloonFightRecord/" + modelname)
# Out:
# saveloop = 0
# learnloop = 0
# ---------------------------------------
# | approxkl           | 3.868611e-05   |
# | clipfrac           | 0.0            |
# | ep_rewmean         | nan            |
# | eplenmean          | nan            |
# | explained_variance | -0.00039       |
# | fps                | 119            |
# | nupdates           | 2              |
# | policy_entropy     | 6.238286       |
# | policy_loss        | -0.00045192536 |
# | serial_timesteps   | 4096           |
# | time_elapsed       | 2.62e-06       |
# | total_timesteps    | 4096           |
# | value_loss         | 528.15796      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00026725585 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | -1.57e-05     |
# | fps                | 168           |
# | nupdates           | 3             |
# ...

# %%
obs = env.reset()
done = False
reward = 0

while not done:
  actions, _ = model.predict(obs)
  obs, rew, done, info = env.step(actions)
  reward += rew

  
print(rew)
# Out:
# [0.]

# %%
# !python /usr/local/lib/python3.6/dist-packages/retro/scripts/playback_movie.py '/gdrive/My Drive/science fair project/2019/BalloonFightRecord/BalloonFight-Nes-Level1-000002.bk2'
# Out:
# ffmpeg version 3.4.6-0ubuntu0.18.04.1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
# ...
